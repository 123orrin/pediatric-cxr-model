# %% [markdown]
# # Classification and Localization of Pediatric Thoracic Disorders using Deep Convolutional Neural Networks
#
# ### Author: Orrin Dahanaggamaarachchi
#
# This notebook is an introduction for the APS360 Final Project. Below is a short trial on how to load Chest X-Ray DICOM images and resize.

# %% [markdown]
# 1. Setup

# %%
# !pip install gdcm
# !pip install pylibjpeg
# !pip install pylibjpeg-libjpeg
# !pip install pydicom
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 31.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 48.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 35.3 MB/s eta 0:00:00
# ...

# %%
import numpy
import matplotlib.pyplot as plt
import pydicom
from skimage.transform import resize

# %% [markdown]
# 2. Test Image Loading and Resizing

# %%
# Load and show original
img = pydicom.dcmread('test.dicom').pixel_array
plt.imshow(img, cmap='grey')

# %%
# Resize and show
img_resized = resize(img, (520, 400), anti_aliasing=True)
plt.imshow(img_resized, cmap='grey')
